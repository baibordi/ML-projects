# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1=pd.read_excel(r'C:\Users\Kyle\Desktop\Middlesex uni\kirish_dataset_train\Fligh\Data_Train.xlsx')
df1.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
df2=pd.read_excel(r'C:\Users\Kyle\Desktop\Middlesex uni\kirish_dataset_train\Fligh\Test_set.xlsx')
df2.head(3)
# Out:
#        Airline Date_of_Journey   Source Destination            Route Dep_Time  \
# 0  Jet Airways       6/06/2019    Delhi      Cochin  DEL → BOM → COK    17:30
# 1       IndiGo      12/05/2019  Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2  Jet Airways      21/05/2019    Delhi      Cochin  DEL → BOM → COK    19:15
#
#    Arrival_Time Duration Total_Stops              Additional_Info
# 0  04:25 07 Jun  10h 55m      1 stop                      No info
# 1         10:20       4h      1 stop                      No info
# 2  19:00 22 May  23h 45m      1 stop  In-flight meal not included

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
#This code combines two DataFrames, df1 and df2, into a single DataFrame called final_df using the concat function from the Pandas library. The concat function concatenates the rows of the two DataFrames along a specified axis
#(by default, axis=0, which means concatenating along rows).
# Assuming df1 and df2 are your DataFrames
final_df = pd.concat([df1, df2])

# %%
final_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# #Changing categotical features to numeric ones

# %% [markdown]
# #Overall, the expression final_df['Date_of_Journey'].str.split('/').str[0] extracts
# the day component from the 'Date_of_Journey' column in the DataFrame final_df by splitting
# each date string at the '/' character and selecting the first part of the resulting substrings.

# %%
final_df['Date_of_Journey'].str.split('/').str[0]
# Out:
# 0       24
# 1        1
# 2        9
# 3       12
# 4       01
#         ..
# 2666     6
# 2667    27
# 2668     6
# 2669     6
# 2670    15
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
final_df['Date']=final_df['Date_of_Journey'].str.split('/').str[0]
final_df['Month']=final_df['Date_of_Journey'].str.split('/').str[1]
final_df['Year']=final_df['Date_of_Journey'].str.split('/').str[2]

# %%
final_df['Date_of_Journey'].str.split('/').str[1]
# Out:
# 0       03
# 1       05
# 2       06
# 3       05
# 4       03
#         ..
# 2666    06
# 2667    03
# 2668    03
# 2669    03
# 2670    06
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
final_df['Date_of_Journey'].str.split('/').str[2]
# Out:
# 0       2019
# 1       2019
# 2       2019
# 3       2019
# 4       2019
#         ...
# 2666    2019
# 2667    2019
# 2668    2019
# 2669    2019
# 2670    2019
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
final_df['Date']=final_df['Date'].astype(int)
final_df['Month']=final_df['Month'].astype(int)
final_df['Year']=final_df['Year'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int32
#  12  Month            13354 non-null  int32
#  13  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.4+ MB

# %%
final_df.drop('Date_of_Journey',axis=1,inplace=True)

# %%
final_df.head(2)
# Out:
#      Airline    Source Destination                  Route Dep_Time  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
#
#    Arrival_Time Duration Total_Stops Additional_Info   Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info  3897.0    24      3
# 1         13:15   7h 25m     2 stops         No info  7662.0     1      5
#
#    Year
# 0  2019
# 1  2019

# %% [markdown]
# #splits each time string in the 'Arrival_Time' column into individual characters, resulting in a list of substrings where each substring represents a single character in the time string.

# %%
final_df['Arrival_Time'].str.split('')
# Out:
# 0       [, 0, 1, :, 1, 0,  , 2, 2,  , M, a, r, ]
# 1                            [, 1, 3, :, 1, 5, ]
# 2       [, 0, 4, :, 2, 5,  , 1, 0,  , J, u, n, ]
# 3                            [, 2, 3, :, 3, 0, ]
# 4                            [, 2, 1, :, 3, 5, ]
#                           ...
# 2666    [, 2, 0, :, 2, 5,  , 0, 7,  , J, u, n, ]
# 2667                         [, 1, 6, :, 5, 5, ]
# 2668    [, 0, 4, :, 2, 5,  , 0, 7,  , M, a, r, ]
# 2669                         [, 1, 9, :, 1, 5, ]
# 2670                         [, 1, 9, :, 1, 5, ]
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final_df['Arrival_Time']=final_df['Arrival_Time'].str.split(' ').str[0]

# %%
final_df.isna().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# dtype: int64

# %%
final_df['Arrival_hour']=final_df['Arrival_Time'].str.split(':').str[0]

# %%
final_df['Arrival_hour']
# Out:
# 0       01
# 1       13
# 2       04
# 3       23
# 4       21
#         ..
# 2666    20
# 2667    16
# 2668    04
# 2669    19
# 2670    19
# Name: Arrival_hour, Length: 13354, dtype: object

# %%
final_df['Arrival_min']=final_df['Arrival_Time'].str.split(':').str[1]

# %%
final_df['Arrival_min']
# Out:
# 0       10
# 1       15
# 2       25
# 3       30
# 4       35
#         ..
# 2666    25
# 2667    55
# 2668    25
# 2669    15
# 2670    15
# Name: Arrival_min, Length: 13354, dtype: object

# %%
final_df['Arrival_hour']=final_df['Arrival_hour'].astype(int)
final_df['Arrival_min']=final_df['Arrival_min'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int32
#  11  Month            13354 non-null  int32
#  12  Year             13354 non-null  int32
#  13  Arrival_hour     13354 non-null  int32
#  14  Arrival_min      13354 non-null  int32
# dtypes: float64(1), int32(5), object(9)
# memory usage: 1.4+ MB

# %%
final_df.drop('Arrival_Time', axis=1, inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Duration         13354 non-null  object
#  6   Total_Stops      13353 non-null  object
#  7   Additional_Info  13354 non-null  object
#  8   Price            10683 non-null  float64
#  9   Date             13354 non-null  int32
#  10  Month            13354 non-null  int32
#  11  Year             13354 non-null  int32
#  12  Arrival_hour     13354 non-null  int32
#  13  Arrival_min      13354 non-null  int32
# dtypes: float64(1), int32(5), object(8)
# memory usage: 1.3+ MB

# %%
final_df['Dep_hour']=final_df['Dep_Time'].str.split(':').str[0]
final_df['Dep_min']=final_df['Dep_Time'].str.split(':').str[1]

# %%
final_df['Dep_hour']
# Out:
# 0       22
# 1       05
# 2       09
# 3       18
# 4       16
#         ..
# 2666    20
# 2667    14
# 2668    21
# 2669    04
# 2670    04
# Name: Dep_hour, Length: 13354, dtype: object

# %%
final_df['Dep_min']
# Out:
# 0       20
# 1       50
# 2       25
# 3       05
# 4       50
#         ..
# 2666    30
# 2667    20
# 2668    50
# 2669    00
# 2670    55
# Name: Dep_min, Length: 13354, dtype: object

# %%
final_df['Dep_hour']=final_df['Dep_hour'].astype(int)
final_df['Dep_min']=final_df['Dep_min'].astype(int)

# %%
final_df.drop('Dep_Time',axis=1,inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int32
#  9   Month            13354 non-null  int32
#  10  Year             13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int32
#  12  Arrival_min      13354 non-null  int32
#  13  Dep_hour         13354 non-null  int32
#  14  Dep_min          13354 non-null  int32
# dtypes: float64(1), int32(7), object(7)
# memory usage: 1.3+ MB

# %%
final_df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
final_df['Total_Stops']=final_df['Total_Stops'].map({'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3,'4 stops':4})

# %%
final_df.head(2)
# Out:
#      Airline    Source Destination                  Route Duration  \
# 0     IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1  Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
#
#    Total_Stops Additional_Info   Price  Date  Month  Year  Arrival_hour  \
# 0          0.0         No info  3897.0    24      3  2019             1
# 1          2.0         No info  7662.0     1      5  2019            13
#
#    Arrival_min  Dep_hour  Dep_min
# 0           10        22       20
# 1           15         5       50

# %%
final_df.drop('Route',axis=1,inplace=True)

# %%
final_df
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          2.0
# 2           Jet Airways     Delhi      Cochin      19h          2.0
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# ...

# %%
final_df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
final_df['duration_hour']=final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13353 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   Date             13354 non-null  int32
#  8   Month            13354 non-null  int32
#  9   Year             13354 non-null  int32
#  10  Arrival_hour     13354 non-null  int32
#  11  Arrival_min      13354 non-null  int32
#  12  Dep_hour         13354 non-null  int32
#  13  Dep_min          13354 non-null  int32
#  14  duration_hour    13354 non-null  object
# dtypes: float64(2), int32(7), object(6)
# memory usage: 1.3+ MB

# %%
# Remove non-numeric characters from the 'duration_hour' column
final_df['duration_hour'] = final_df['duration_hour'].str.replace('m', '')

# Convert the 'duration_hour' column to integers
final_df['duration_hour'] = final_df['duration_hour'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Total_Stops      13353 non-null  float64
#  5   Additional_Info  13354 non-null  object
#  6   Price            10683 non-null  float64
#  7   Date             13354 non-null  int32
#  8   Month            13354 non-null  int32
#  9   Year             13354 non-null  int32
#  10  Arrival_hour     13354 non-null  int32
#  11  Arrival_min      13354 non-null  int32
#  12  Dep_hour         13354 non-null  int32
#  13  Dep_min          13354 non-null  int32
#  14  duration_hour    13354 non-null  int32
# dtypes: float64(2), int32(8), object(5)
# memory usage: 1.2+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder=LabelEncoder()
final_df['Airline']=labelencoder.fit_transform(final_df['Airline'])
final_df['Source']=labelencoder.fit_transform(final_df['Source'])
final_df['Destination']=labelencoder.fit_transform(final_df['Destination'])
final_df['Additional_Info']=labelencoder.fit_transform(final_df['Additional_Info'])

# %%
final_df.drop('Duration',axis=1,inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  int32
#  1   Source           13354 non-null  int32
#  2   Destination      13354 non-null  int32
#  3   Total_Stops      13353 non-null  float64
#  4   Additional_Info  13354 non-null  int32
#  5   Price            10683 non-null  float64
#  6   Date             13354 non-null  int32
#  7   Month            13354 non-null  int32
#  8   Year             13354 non-null  int32
#  9   Arrival_hour     13354 non-null  int32
#  10  Arrival_min      13354 non-null  int32
#  11  Dep_hour         13354 non-null  int32
#  12  Dep_min          13354 non-null  int32
#  13  duration_hour    13354 non-null  int32
# dtypes: float64(2), int32(12)
# memory usage: 939.0 KB

# %%
# Box plot to compare price across different destinations
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.boxplot(x='Destination', y='Price', data=final_df)
plt.title('Comparison of Price Across Destinations')
plt.xlabel('Destination')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Destination', y='Price', data=final_df, palette='viridis')
plt.title('Average Price by Destination')
plt.xlabel('Destination')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # The longer the duration hours become the more price we have for the flight

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming final_df contains your DataFrame

# Sort the DataFrame by price in ascending order
#final_df_sorted = final_df.sort_values(by='Price')

# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='duration_hour', y='Price', data=final_df_sorted, palette='viridis')
plt.title('Average Price by Destination (Sorted)')
plt.xlabel('duration_hour')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming final_df contains your DataFrame

# Create a scatter plot
plt.figure(figsize=(12, 6))
sns.scatterplot(x='duration_hour', y='Destination', data=final_df, alpha=0.5)
plt.title('Relationship between Departure Hour and Destination')
plt.xlabel('Departure Hour')
plt.ylabel('Destination')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Hypothesis: The more stopes exist in a flight the more price will be charged

# %%
# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Total_Stops', y='Price', data=final_df, palette='viridis')
plt.title('Price by Total Stops')
plt.xlabel('Total Stops')
plt.ylabel('Price')
plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %%
# The price of the flight has some fluctuations based on the Monthes

# %%
# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Month', y='Price', data=final_df, palette='viridis')
plt.title('Price by Monthes')
plt.xlabel('Month')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %%
# The price of the flight has some fluctuations based on the days

# %%
# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Date', y='Price', data=final_df, palette='viridis')
plt.title('Price by Date')
plt.xlabel('Date')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %%
final_df
# Out:
#       Airline  Source  Destination  Total_Stops  Additional_Info    Price  \
# 0           3       0            5          0.0                8   3897.0
# 1           1       3            0          2.0                8   7662.0
# 2           4       2            1          2.0                8  13882.0
# 3           3       3            0          1.0                8   6218.0
# 4           3       0            5          1.0                8  13302.0
# ...       ...     ...          ...          ...              ...      ...
# 2666        1       3            0          1.0                8      NaN
# 2667        3       3            0          0.0                8      NaN
# 2668        4       2            1          1.0                8      NaN
# 2669        1       2            1          1.0                8      NaN
# 2670        6       2            1          1.0                8      NaN
#
#       Date  Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min  \
# ...

# %%
final_df_test=final_df[final_df['Price'].isnull()]
final_df_test
# Out:
#       Airline  Source  Destination  Total_Stops  Additional_Info  Price  Date  \
# 0           4       2            1          1.0                8    NaN     6
# 1           3       3            0          1.0                8    NaN    12
# 2           4       2            1          1.0                5    NaN    21
# 3           6       2            1          1.0                8    NaN    21
# 4           0       0            2          0.0                8    NaN    24
# ...       ...     ...          ...          ...              ...    ...   ...
# 2666        1       3            0          1.0                8    NaN     6
# 2667        3       3            0          0.0                8    NaN    27
# 2668        4       2            1          1.0                8    NaN     6
# 2669        1       2            1          1.0                8    NaN     6
# 2670        6       2            1          1.0                8    NaN    15
#
# ...

# %%
final_df_train=final_df[~final_df['Price'].isnull()]
final_df_train
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info    Price  \
# 0            3       0            5          0.0                8   3897.0
# 1            1       3            0          2.0                8   7662.0
# 2            4       2            1          2.0                8  13882.0
# 3            3       3            0          1.0                8   6218.0
# 4            3       0            5          1.0                8  13302.0
# ...        ...     ...          ...          ...              ...      ...
# 10678        0       3            0          0.0                8   4107.0
# 10679        1       3            0          0.0                8   4145.0
# 10680        4       0            2          0.0                8   7229.0
# 10681       10       0            5          0.0                8  12648.0
# 10682        1       2            1          2.0                8  11753.0
#
# ...

# %%
Y = final_df_train['Price']

# %%
Y
# Out:
# 0         3897.0
# 1         7662.0
# 2        13882.0
# 3         6218.0
# 4        13302.0
#           ...
# 10678     4107.0
# 10679     4145.0
# 10680     7229.0
# 10681    12648.0
# 10682    11753.0
# Name: Price, Length: 10683, dtype: float64

# %%
#X=final_df_train.drop('Price', axis=1, inplace=True)

# %%
X = final_df_train.drop('Price', axis=1)

# %%
X
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Date  \
# 0            3       0            5          0.0                8    24
# 1            1       3            0          2.0                8     1
# 2            4       2            1          2.0                8     9
# 3            3       3            0          1.0                8    12
# 4            3       0            5          1.0                8     1
# ...        ...     ...          ...          ...              ...   ...
# 10678        0       3            0          0.0                8     9
# 10679        1       3            0          0.0                8    27
# 10680        4       0            2          0.0                8    27
# 10681       10       0            5          0.0                8     1
# 10682        1       2            1          2.0                8     9
#
#        Month  Year  Arrival_hour  Arrival_min  Dep_hour  Dep_min  \
# ...

# %%
from sklearn.model_selection import train_test_split

# Assuming X contains your features and Y contains your target variable

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Print the shapes of the training and testing sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("Y_train shape:", Y_train.shape)
print("Y_test shape:", Y_test.shape)
# Out:
# X_train shape: (8546, 13)
# X_test shape: (2137, 13)
# Y_train shape: (8546,)
# Y_test shape: (2137,)

# %%
X.shape
# Out:
# (10683, 13)

# %%
Y.shape
# Out:
# (10683,)

# %%
# Extract counts of NaN values for each column
nan_counts = final_df_train.isnull().sum()
print("Counts of NaN values for each column:")
print(nan_counts)
# Out:
# Counts of NaN values for each column:
# Airline            0
# Source             0
# Destination        0
# Total_Stops        1
# Additional_Info    0
# Price              0
# Date               0
# Month              0
# Year               0
# Arrival_hour       0
# Arrival_min        0
# Dep_hour           0
# Dep_min            0
# duration_hour      0
# dtype: int64

# %%
# Importing pandas library
import pandas as pd

# Assuming 'df' is your DataFrame containing the data
# Replace 'df' with the name of your DataFrame

# Calculate the mode of the Total_Stops column
mode_total_stops = final_df_train['Total_Stops'].mode()[0]

# Impute the missing value with the mode
final_df_train['Total_Stops'].fillna(mode_total_stops, inplace=True)

# Verify if the NaN value is filled
print("Counts of NaN values for each column after imputation:")
print(final_df_train.isnull().sum())
# Out:
# Counts of NaN values for each column after imputation:
# Airline            0
# Source             0
# Destination        0
# Total_Stops        0
# Additional_Info    0
# Price              0
# Date               0
# Month              0
# Year               0
# Arrival_hour       0
# Arrival_min        0
# Dep_hour           0
# Dep_min            0
# duration_hour      0
# dtype: int64
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_22344\2202004142.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df_train['Total_Stops'].fillna(mode_total_stops, inplace=True)

# %% [markdown]
# The performance of linear regression depends on the linearity of the relationships in the data. So, it can be ssen that here the result of using linear regreesion is not good.So, another technque will be used in the next part

# %%
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Instantiate SimpleImputer with strategy='mean'
imputer = SimpleImputer(strategy='mean')

# Fit the imputer on X_train
imputer.fit(X_train)

# Transform X_train and X_test with the trained imputer
X_train_imputed = imputer.transform(X_train)
X_test_imputed = imputer.transform(X_test)

# Model Selection and Training
model = LinearRegression()  # Choose the model (e.g., Linear Regression)
model.fit(X_train_imputed, Y_train)  # Train the model

# Model Evaluation
Y_pred = model.predict(X_test_imputed)  # Make predictions on the testing data
mse = mean_squared_error(Y_test, Y_pred)  # Calculate Mean Squared Error
rmse = mean_squared_error(Y_test, Y_pred, squared=False)  # Calculate Root Mean Squared Error

print("R-squared:", r2)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Calculate R-squared
r2 = r2_score(Y_test, Y_pred)
# Out:
# R-squared: 0.42971692339635126
# Mean Squared Error: 12069451.675368417
# Root Mean Squared Error: 3474.1116382995547

# %%
from sklearn.impute import SimpleImputer

# Initialize the SimpleImputer with strategy='mean'
imputer = SimpleImputer(strategy='mean')

# Fit the imputer on the training data
imputer.fit(X_train)

# Transform both training and testing data
X_train_imputed = imputer.transform(X_train)
X_test_imputed = imputer.transform(X_test)

# Now you can train the RandomForestRegressor model with imputed data
rf_model.fit(X_train_imputed, Y_train)

# Make predictions
rf_y_pred = rf_model.predict(X_test_imputed)

# Calculate R-squared for Random Forest Regressor
rf_r2 = r2_score(Y_test, rf_y_pred)
print("Random Forest R-squared:", rf_r2)
# Out:
# Random Forest R-squared: 0.8542123851494074

# %% [markdown]
# #The Random Forest Regressor model achieved an R-squared value of approximately 0.854, indicating that approximately 85.4% of the variance in the target variable (Price) was explained by the features included in the model. This suggests that the model captures a significant portion of the underlying patterns in the data, demonstrating its effectiveness in predicting flight prices based on various input features."

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

# Define the RandomForestRegressor model with parameters
best_rf_model = RandomForestRegressor(random_state=42, n_estimators=100, max_depth=10)

# Perform k-fold cross-validation
cv_scores = cross_val_score(best_rf_model, X_train_imputed, Y_train, cv=5, scoring='r2')

# Print the R-squared scores for each fold
print("Cross-validated R-squared scores:", cv_scores)

# Train the RandomForestRegressor model on the entire training data
best_rf_model.fit(X_train_imputed, Y_train)
# Out:
# Cross-validated R-squared scores: [0.88089395 0.87055864 0.83879861 0.81984878 0.85027762]
# RandomForestRegressor(max_depth=10, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# Define the RandomForestRegressor model with parameters
best_rf_model = RandomForestRegressor(random_state=42, n_estimators=100, max_depth=10)

# Perform k-fold cross-validation
cv_scores = cross_val_score(best_rf_model, X_train_imputed, Y_train, cv=5, scoring='r2')

# Print the R-squared scores for each fold
print("Cross-validated R-squared scores:", cv_scores)

# Train the RandomForestRegressor model on the entire training data
best_rf_model.fit(X_train_imputed, Y_train)

# Get feature importances
feature_importances = best_rf_model.feature_importances_

# Create a DataFrame to display feature importances
feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Print the feature importances
print("\nFeature Importances:")
print(feature_importance_df)

# Plot the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()
# Out:
# Cross-validated R-squared scores: [0.88089395 0.87055864 0.83879861 0.81984878 0.85027762]
#
# Feature Importances:
#             Feature  Importance
# 12    duration_hour    0.463859
# 0           Airline    0.155723
# 5              Date    0.091617
# 4   Additional_Info    0.078215
# 3       Total_Stops    0.051736
# 6             Month    0.039526
# 2       Destination    0.037236
# 10         Dep_hour    0.021791
# 8      Arrival_hour    0.021300
# 11          Dep_min    0.016069
# 9       Arrival_min    0.014952
# 1            Source    0.007976
# 7              Year    0.000000
