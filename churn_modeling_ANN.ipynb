# %%
import pandas as pd

# %%
#binary classifiction

# %%
dataset=pd.read_csv(r"Downloads/Churn_Modelling.csv")
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
x=dataset.iloc[:,3:13]
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
y=dataset.iloc[:,13]
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
Geography=pd.get_dummies(x['Geography'],drop_first=True)
Geography
# Out:
#       Germany  Spain
# 0       False  False
# 1       False   True
# 2       False  False
# 3       False  False
# 4       False   True
# ...       ...    ...
# 9995    False  False
# 9996    False  False
# 9997    False  False
# 9998     True  False
# 9999    False  False
#
# [10000 rows x 2 columns]

# %%
Gender=pd.get_dummies(x['Gender'])
Gender
# Out:
#       Female   Male
# 0       True  False
# 1       True  False
# 2       True  False
# 3       True  False
# 4       True  False
# ...      ...    ...
# 9995   False   True
# 9996   False   True
# 9997    True  False
# 9998   False   True
# 9999    True  False
#
# [10000 rows x 2 columns]

# %%
x
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
x=x.drop(['Geography','Gender'],axis=1)
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary
# 0                  1        101348.88
# 1                  1        112542.58
# ...

# %%
pd.concat([x, Geography,Gender], axis=1)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Female   Male
# 0                  1        101348.88    False  False    True  False
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler 
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
sc
# Out:
# StandardScaler()

# %%
x_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ...,  0.64259497,
#         -1.03227043,  1.10643166],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  0.64259497,
#          0.9687384 , -0.74866447],
#        [-1.19119591, -0.94312892, -1.031415  , ...,  0.64259497,
#         -1.03227043,  1.48533467],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ...,  0.64259497,
#         -1.03227043,  1.41231994],
#        [-0.62420521, -0.08179119,  1.39076231, ...,  0.64259497,
#          0.9687384 ,  0.84432121],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  0.64259497,
#         -1.03227043,  0.32472465]])

# %%
x_test
# Out:
# array([[-0.55204276, -0.36890377,  1.04473698, ...,  0.64259497,
#          0.9687384 ,  1.61085707],
#        [-1.31490297,  0.10961719, -1.031415  , ...,  0.64259497,
#         -1.03227043,  0.49587037],
#        [ 0.57162971,  0.30102557,  1.04473698, ...,  0.64259497,
#          0.9687384 , -0.42478674],
#        ...,
#        [-0.74791227, -0.27319958, -1.37744033, ...,  0.64259497,
#         -1.03227043,  0.71888467],
#        [-0.00566991, -0.46460796, -0.33936434, ...,  0.64259497,
#          0.9687384 , -1.54507805],
#        [-0.79945688, -0.84742473,  1.04473698, ...,  0.64259497,
#         -1.03227043,  1.61255917]])

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU,ReLU,ReLU,PReLU, ELU
from tensorflow.keras.layers import Dropout

# %%
classifier=Sequential()

# %%
#adding input layer
classifier.add(Dense(units=11,activation='relu'))

# %%
#adding the fist hidden layer
classifier.add(Dense(units=7,activation='relu'))

# %%
#adding the second layer hidden layer
classifier.add(Dense(units=6,activation='relu'))

# %%
classifier.add(Dense(units=1,activation='sigmoid'))

# %%
classifier.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
import tensorflow

# %%
opt=tensorflow.keras.optimizers.Adam(learning_rate=0.01)

# %%
opt

# %%
import tensorflow as tf
tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.0001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0,
)

# %%
model_history=classifier.fit(x_train,y_train, validation_split=0.33, batch_size=10, epochs=10)
# Out:
# Epoch 1/10
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8542 - loss: 0.3608 - val_accuracy: 0.8398 - val_loss: 0.3985
# Epoch 2/10
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8576 - loss: 0.3462 - val_accuracy: 0.8485 - val_loss: 0.3750
# Epoch 3/10
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8546 - loss: 0.3624 - val_accuracy: 0.8436 - val_loss: 0.3901
# Epoch 4/10
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8549 - loss: 0.3484 - val_accuracy: 0.8410 - val_loss: 0.3739
# Epoch 5/10
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8504 - loss: 0.3682 - val_accuracy: 0.8451 - val_loss: 0.3765
# Epoch 6/10
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8502 - loss: 0.3591 - val_accuracy: 0.8425 - val_loss: 0.3835
# Epoch 7/10
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8615 - loss: 0.3431 - val_accuracy: 0.8474 - val_loss: 0.3839
# Epoch 8/10
# ...

# %%
model_history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper right')
plt.show()

# %%
y_pred=classifier.predict(x_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
y_pred=classifier.predict(x_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

# Convert continuous predictions to discrete labels
y_pred_discrete = np.round(y_pred)  # Example: Round continuous predictions to the nearest integer

# Ensure both y_test and y_pred_discrete have the same data type and contain discrete class labels
# Ensure they are numpy arrays or convert them if necessary
y_test = np.array(y_test)
y_pred_discrete = np.array(y_pred_discrete)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred_discrete)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[1530   65]
#  [ 220  185]]

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(y_pred,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 score=accuracy_score(y_pred,y_test)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
#     195     # the function to delegate validation to the estimator, but we replace
#     196     # the name of the estimator by the name of the function in the error
#     197     # message to avoid confusion.
#     198     msg = re.sub(
#     199         r"parameter of \w+ must be",
# ...

# %%
from sklearn.metrics import accuracy_score
import numpy as np

# Convert continuous predictions to discrete labels
y_pred_discrete = np.round(y_pred)  # Example: Round continuous predictions to the nearest integer

# Ensure both y_test and y_pred_discrete have the same data type and contain discrete class labels
# Ensure they are numpy arrays or convert them if necessary
y_test = np.array(y_test)
y_pred_discrete = np.array(y_pred_discrete)

# Compute accuracy score
score = accuracy_score(y_test, y_pred_discrete)

print("Accuracy Score:", score)
# Out:
# Accuracy Score: 0.8575

# %%
classifier.get_weights()
# Out:
# [array([[ 0.29844844, -0.6501988 ,  0.09419089, -0.1882099 ,  0.09556864,
#          -0.35364053,  0.23754677, -0.07046728,  0.08722801, -1.447824  ,
#           0.03800858],
#         [ 1.0202928 , -0.32851958,  1.49314   , -1.7444152 ,  0.2769186 ,
#           0.89891064, -2.681316  ,  0.10025109, -1.8984067 , -0.3407402 ,
#           0.29295263],
#         [ 0.51135594,  0.70474386,  0.16618074,  0.1997272 ,  0.3508172 ,
#           0.40847027, -0.07976414,  0.16894054,  0.36773095,  0.37860417,
#          -0.30466217],
#         [-0.27353743, -1.4810636 ,  0.1530385 ,  0.6242538 , -2.518795  ,
#          -0.23096563, -0.3645178 , -0.09365878, -0.28583723,  0.16649354,
#          -1.0276055 ],
#         [-0.48200035, -2.0606647 ,  2.0846493 , -0.89645547,  0.19041523,
#          -2.4298096 , -0.18771417,  2.0298727 , -0.26561722,  0.2695529 ,
#          -0.19779737],
#         [ 0.38096094,  0.0159513 , -0.08978324, -0.13583861, -0.37653473,
# ...
